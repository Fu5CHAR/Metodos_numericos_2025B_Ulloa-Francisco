# %%
import numpy as np
from scipy import optimize

def f(x):
    return x**5 + 5.25*x**4 + 4.125*x**3 - 9.125*x**2 - 14.626*x -5.625



print(optimize.newton(f,x0=0))
# Out:
# -0.9482926716938815

# %%
import numpy as np
from scipy import optimize

def f(x):
    return x**5 + 5.25*x**4 + 4.125*x**3 - 9.125*x**2 - 14.626*x -5.625



print(optimize.newton(f,x0=100))
# Out:
# 1.5000182854722726

# %%
import numpy as np
from scipy import optimize

def f(x):
    return x**5 + 5.25*x**4 + 4.125*x**3 - 9.125*x**2 - 14.626*x -5.625



print(optimize.newton(f,x0=-100))
# Out:
# -3.7500343446225406
