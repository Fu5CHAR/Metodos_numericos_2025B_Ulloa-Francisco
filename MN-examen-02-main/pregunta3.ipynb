# %% [markdown]
# ## Resolución pregunta 3

# %%
import numpy as np
import math

def redondeo(num, cifras):
    magnitud = math.floor(math.log10(abs(num)))
    decimales = cifras - 1 - magnitud 
    return round(num,decimales) 


def metodo_logaritmo(x):
    k=0
    temp=x
    r=0
    logaritmo = 0
    for k in range(0,5):

        temp = math.sqrt(temp)
    r = temp - 1
    
    logaritmo = r * 1/math.log(10)
    return  redondeo(32*logaritmo,6), r


def calculo_error(log_calcu, log_real):
    error = abs(log_real-log_calcu)/abs(log_calcu)

    return redondeo(error,6)

# %%
x=2
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.304314 para: 2
# logaritmo real 0.3010299956639812
# error 0.0107915

# %%
x=3
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.485406 para: 3
# logaritmo real 0.47712125471966244
# error 0.0170677

# %%
x=4
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.615292 para: 4
# logaritmo real 0.6020599913279624
# error 0.0215053

# %%
x=5
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.716846 para: 5
# logaritmo real 0.6989700043360189
# error 0.024937

# %%
x=6
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.800349 para: 6
# logaritmo real 0.7781512503836436
# error 0.0277351

# %%
x=7
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.871322 para: 7
# logaritmo real 0.8450980400142568
# error 0.0300967

# %%
x=8
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.933079 para: 8
# logaritmo real 0.9030899869919435
# error 0.0321398

# %%
x=9
logaritmo, rmas1 = metodo_logaritmo(x)
print('logaritmo base 10 calculado:',logaritmo, 'para:', x)
print('logaritmo real',np.log10(x))
print('error',calculo_error(logaritmo,np.log10(x)))
# Out:
# logaritmo base 10 calculado: 0.987766 para: 9
# logaritmo real 0.9542425094393249
# error 0.0339387
