# %% [markdown]
# # Mínimos cuadrados
# ## Prueba 02
# Interpole los siguientes conjuntos de datos con la función correspondiente.

# %% [markdown]
# La ecuación de la línea es:
#
# $ y(x) = a_1 x + a_0 $
#
# Al realizar el proceso de mínimos cuadrados queda el siguiente sistema de ecuaciones:
#
#
# $( \sum_i (y_i - a_1 x_i - a_0) , \sum_i (y_i - a_1 x_i - a_0)x_i ) = 0$

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_2_prueba(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_2 = 0 
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += yi

        c_2 += (xi**2)
        # coeficiente del parámetro 1
        c_1 += xi 

        # coeficiente del parámetro 0
        c_0 = len(xs)

    return (c_2, c_1, c_0, c_ind)


def der_parcial_1_prueba(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_2 = 0 
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        c_2 += (xi**3)
        # coeficiente del parámetro 1
        c_1 += (xi**2)

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_2, c_1, c_0, c_ind)
def der_parcial_0_prueba(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += (xi**2) * yi

        c_2 += xi**4
        # coeficiente del parámetro 1
        c_1 += xi**3

        # coeficiente del parámetro 0
        c_0 += xi**2

    return (c_2, c_1, c_0, c_ind)

# %% [markdown]
# # Conjunto de datos de ejemplo

# %%
xs = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys = [
    -12.7292,
    -7.5775,
    -7.7390,
    -4.1646,
    -4.5382,
    2.2048,
    4.3369,
    2.2227,
    9.0625,
    7.1860,
]

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])
# Out:
# [02-09 21:22:54][INFO] 2026-02-09 21:22:54.311857
# [02-09 21:22:54][INFO] 2026-02-09 21:22:54.518655
# [02-09 21:22:54][INFO] Se ajustarán 2 parámetros.
# [02-09 21:22:54][INFO]
# [[101.8525926    0.         209.87476711]
#  [  0.          10.         -11.7356    ]]

# %%
import numpy as np
import matplotlib.pyplot as plt

m, b = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])

x = np.linspace(-5, 5, 100)

y = [m * xi + b for xi in x]

plt.scatter(xs, ys, label="Datos")
plt.plot(x, y, color="red", label=r"$ y = a_1 x + a_0 $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()
# Out:
# [02-09 21:22:57][INFO] Se ajustarán 2 parámetros.
# [02-09 21:22:57][INFO]
# [[101.8525926    0.         209.87476711]
#  [  0.          10.         -11.7356    ]]

# %% [markdown]
# ## Conjunto de datos 1

# %%
xs1 = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys1 = [
    57.2441,
    33.0303,
    16.4817,
    7.0299,
    0.5498,
    0.7117,
    3.4185,
    12.1767,
    24.9167,
    44.2495,
]

# %%
plt.scatter(xs1, ys1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Conjunto de datos 1")
plt.show()

# %%
import numpy as np  
def error_prom_max(x, y, f):
    y_calculado = [0]*len(y)
    error = [0]*len(y)
    prom = 0
    max_error=0
    x_max_error = 0
    y_max_error = 0
    for i in range(len(x)):
        y_calculado[i] = f(x[i])
        error[i] = abs( y[i] - y_calculado[i])/abs(y[i])
        if max_error < error[i]:
            max_error = error[i]
            y_max_error = y_calculado[i]
            x_max_error = x[i]  

    for i in range(len(error)):
        prom += error[i]         
    prom = prom / len(error)

    return prom, max_error, x_max_error, y_max_error

# %% [markdown]
# Interpole el conjunto de datos 1 usando la función cuadrática.

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0_prueba, der_parcial_1_prueba, der_parcial_2_prueba])
# Out:
# [02-09 21:23:41][INFO] Se ajustarán 3 parámetros.
# [02-09 21:23:41][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]
# [02-09 21:23:41][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]

# %%
import numpy as np
import matplotlib.pyplot as plt

c,m, b = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0_prueba, der_parcial_1_prueba, der_parcial_2_prueba])

x = np.linspace(-5, 5, 100)

# Cálculo vectorizado de la parábola: y = -c x^2 + m x + b
y = c * x**2 + m * x + b
y_max= c * (0.5556)**2 + m * (0.5556) + b

plt.scatter(0.5556, y_max, marker='o', color='black', label='Punto con mayor error')
plt.scatter(xs1, ys1, label="Datos")
plt.plot(x, y, color="red", label=r"$ y = c x^2 + m x + b $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos 1 (cuadrática)")
plt.legend()
plt.show()
# Out:
# [02-09 21:26:26][INFO] Se ajustarán 3 parámetros.
# [02-09 21:26:27][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]
# [02-09 21:26:27][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]

# %%
def funcion(x):
    return c * x**2 + m * x + b

prom, max_error,x_max, y_max  = error_prom_max(xs1, ys1, funcion)

print('error promedio: ', prom)
print('\nerror maximo: ', max_error)
print('\nmax error x: ', x_max)
print('\nmax error y: ', y_max)
# Out:
# error promedio:  0.2343615548296148
#
# error maximo:  1.8956822173296963
#
# max error x:  0.5556
#
# max error y:  -0.6374570340735449

# %% [markdown]
# ## Conjunto de datos 2

# %%
import math

def der_parcial_1_exp(xs: list, ys: list) -> tuple[float, float, float]:
    Ys = [math.log(y) for y in ys]

    c_ind = sum(Ys)
    c_1 = sum(xs)
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0_exp(xs: list, ys: list) -> tuple[float, float, float]:
    Ys = [math.log(y) for y in ys]

    c_1 = 0
    c_0 = 0
    c_ind = 0

    for xi, Yi in zip(xs, Ys):
        c_ind += xi * Yi
        c_1 += xi * xi
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
xs2 = [
    0.0003,
    0.0822,
    0.2770,
    0.4212,
    0.4403,
    0.5588,
    0.5943,
    0.6134,
    0.9070,
    1.0367,
    1.1903,
    1.2511,
    1.2519,
    1.2576,
    1.6165,
    1.6761,
    2.0114,
    2.0557,
    2.1610,
    2.6344,
]
ys2 = [
    1.1017,
    1.5021,
    0.3844,
    1.3251,
    1.7206,
    1.9453,
    0.3894,
    0.3328,
    1.2887,
    3.1239,
    2.1778,
    3.1078,
    4.1856,
    3.3640,
    6.0330,
    5.8088,
    10.5890,
    11.5865,
    11.8221,
    26.5077,
]

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

m, b = ajustar_min_cuadrados(xs2, ys2, gradiente=[der_parcial_0_exp, der_parcial_1_exp])
# Out:
# [02-09 21:38:45][INFO] 2026-02-09 21:38:45.959655
# [02-09 21:38:46][INFO] 2026-02-09 21:38:46.275751
# [02-09 21:38:46][INFO] Se ajustarán 2 parámetros.
# [02-09 21:38:46][INFO]
# [[22.0372     20.         19.05727035]
#  [ 0.         -9.57184451  5.82589171]]

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(min(xs2), max(xs2), 100)


y = np.exp([m*xi + b for xi in x])
y_max= np.exp(m*0.6134 + b)

plt.scatter(0.6134, y_max, marker='o', color='black', label='Punto con mayor error')

plt.scatter(xs2, ys2, label="Datos")
plt.plot(x, y, color="red", label=r"$ y = a_0 e^{a_1 x} $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos 2 (exponencial)")
plt.legend()
plt.show()

# %%
plt.scatter(xs2, ys2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Conjunto de datos 2")
plt.show()

# %%
def funcion(x):
    return np.exp(m*x + b)

prom2, max_error2, x_max2, y_max2 = error_prom_max(xs2, ys2, funcion)

print('error promedio: ', prom2)
print('\nerror maximo: ', max_error2)
print('\nvalor de x donde ocurre el error maximo: ', x_max2)
print('\nvalor de y donde ocurre el error maximo: ', y_max2)
# Out:
# error promedio:  0.5163778917913228
#
# error maximo:  2.899510119858577
#
# valor de x donde ocurre el error maximo:  0.6134
#
# valor de y donde ocurre el error maximo:  1.2977569678889345

# %% [markdown]
# Interpole el conjunto de datos 2 usando la función exponencial.
