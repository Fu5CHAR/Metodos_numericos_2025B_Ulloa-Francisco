# %% [markdown]
# # Eliminación Gaussiana con sustitución hacia atrás

# %%
# %load_ext autoreload

# %%
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[1, 1, 0, 3, 4], [2, 1, -1, 1, 1], [3, -1, -1, 2, -3], [-1, 2, 3, -1, 4]]

eliminacion_gaussiana(Ab)
# Out:
# [12-25 17:59:09][INFO] 2025-12-25 17:59:09.781098
# [12-25 17:59:09][INFO]
# [[  1   1   0   3   4]
#  [  0  -1  -1  -5  -7]
#  [  0  -4  -1  -7 -15]
#  [  0   3   3   2   8]]
# [12-25 17:59:09][INFO]
# [[  1   1   0   3   4]
#  [  0  -1  -1  -5  -7]
#  [  0   0   3  13  13]
#  [  0   0   0 -13 -13]]
# [12-25 17:59:09][INFO]
# [[  1   1   0   3   4]
#  [  0  -1  -1  -5  -7]
#  [  0   0   3  13  13]
#  [  0   0   0 -13 -13]]
# array([-1.,  2.,  0.,  1.])

# %%
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[1, -1, 2, -1, -8], [2, -2, 3, -3, -20], [1, 1, 1, 0, -2], [1, -1, 4, 3, 4]]

eliminacion_gaussiana(Ab)
# Out:
# [12-25 17:59:14][INFO]
# [[ 1 -1  2 -1 -8]
#  [ 0  0 -1 -1 -4]
#  [ 0  2 -1  1  6]
#  [ 0  0  2  4 12]]
# [12-25 17:59:14][INFO]
# [[ 1 -1  2 -1 -8]
#  [ 0  2 -1  1  6]
#  [ 0  0 -1 -1 -4]
#  [ 0  0  2  4 12]]
# [12-25 17:59:14][INFO]
# [[ 1 -1  2 -1 -8]
#  [ 0  2 -1  1  6]
#  [ 0  0 -1 -1 -4]
#  [ 0  0  0  2  4]]
# array([-7.,  3.,  2.,  2.])

# %% [markdown]
# # Soluciones infinitas
# El siguiente sistema de ecuaciones tiene soluciones infinitas:
#
# |   |   |   |   |
# |---|---|---|---|
# | 1 | 1 | 1 | 4 |
# | 2 | 2 | 1 | 6 |
# | 1 | 1 | 2 | 6 |

# %%
# %load_ext autoreload
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[1, 1, 1, 4], [2, 2, 1, 6], [1, 1, 2, 6]]

eliminacion_gaussiana(Ab)
# Out:
# [12-22 15:28:36][INFO]
# [[ 1  1  1  4]
#  [ 0  0 -1 -2]
#  [ 0  0  1  2]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 7
#       3 from src import eliminacion_gaussiana
#       5 Ab = [[1, 1, 1, 4], [2, 2, 1, 6], [1, 1, 2, 6]]
# ----> 7 eliminacion_gaussiana(Ab)
#
# File c:\Users\Laboratorio IA\OneDrive\doctorado\profesor\talleres\taller gauss\src\linear_sist_methods.py:65, in eliminacion_gaussiana(A)
#      61         p = pi
#      63 if p is None:
#      64     # no pivot found.
# ---> 65     raise ValueError("No existe solución única.")
#      67 if p != i:
#      68     # swap rows
#      69     logging.debug(f"Intercambiando filas {i} y {p}")
#
# ValueError: No existe solución única.

# %% [markdown]
# # Sin solución
# El siguiente sistema de ecuaciones no tiene solución:
#
# |   |   |   |   |
# |---|---|---|---|
# | 1 | 1 | 1 | 4 |
# | 2 | 2 | 1 | 4 |
# | 1 | 1 | 2 | 6 |

# %%
# %load_ext autoreload
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[1, 1, 1, 4], [2, 2, 1, 4], [1, 1, 2, 6]]

eliminacion_gaussiana(Ab)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 7
#       3 from src import eliminacion_gaussiana
#       5 A = [[1, 1, 1, 4], [2, 2, 1, 4], [1, 1, 2, 6]]
# ----> 7 eliminacion_gaussiana(A)
#
# File c:\Users\Laboratorio IA\OneDrive\doctorado\profesor\2024 - A\Métodos numéricos\clases\python\src\gaussian_elimination.py:65, in eliminacion_gaussiana(A)
#      61         p = pi
#      63 if p is None:
#      64     # no pivot found.
# ---> 65     raise ValueError("No existe solución única.")
#      67 if p != i:
#      68     # swap rows
#      69     _aux = A[i, :].copy()
#
# ValueError: No existe solución única.

# %%
# %autoreload 2
from src import eliminacion_gaussiana
Fe=[[1,1,0,1,2],[2,1,-1,1,1],[4,-1,-2,2,0],[3,-1,-1,2,-3]]
eliminacion_gaussiana(Fe)
# Out:
# [01-05 20:12:20][INFO] 2026-01-05 20:12:20.877939
# [01-05 20:12:22][INFO]
# [[ 1  1  0  1  2]
#  [ 0 -1 -1 -1 -3]
#  [ 0 -5 -2 -2 -8]
#  [ 0 -4 -1 -1 -9]]
# [01-05 20:12:22][INFO]
# [[ 1  1  0  1  2]
#  [ 0 -1 -1 -1 -3]
#  [ 0  0  3  3  7]
#  [ 0  0  3  3  3]]
# [01-05 20:12:22][INFO]
# [[ 1  1  0  1  2]
#  [ 0 -1 -1 -1 -3]
#  [ 0  0  3  3  7]
#  [ 0  0  0  0 -4]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 from src import eliminacion_gaussiana
#       3 Fe=[[1,1,0,1,2],[2,1,-1,1,1],[4,-1,-2,2,0],[3,-1,-1,2,-3]]
# ----> 4 eliminacion_gaussiana(Fe)
#
# File c:\Users\pc\Videos\2025B\metodos_numericos\Metodos_numericos_2025B_Ulloa-Francisco\Talleres\Taller06_Ulloa Francisco\taller-gauss-main\src\linear_sist_methods.py:82, in eliminacion_gaussiana(A)
#      79     logging.info(f"\n{A}")
#      81 if A[n - 1, n - 1] == 0:
# ---> 82     raise ValueError("No existe solución única.")
#      84     print(f"\n{A}")
#      85 # --- Sustitución hacia atrás
#
# ValueError: No existe solución única.
